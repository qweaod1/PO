# %% [markdown]
# # Bardzo szybkie przypomnienie podstaw języka Python
#
#
# ## Krótki plan
#
# - **Krótki wstęp**
# - **Instalacja Pythona**
# - **Proste typy danych**
# - **Moduły Pythona**
# - **Instrukcja warunkowa i instrukcje iteracyjne**:
# - **Funkcje**
# - **Łańcuchy znaków**
# - **Krotki**
# - **Listy**
# - **Pliki**
# - **Słowniki**
#
#
# ## Parę słów wstepu
# ### Charakterystyka języka Python
# - Jest interpretowanym językiem programowania wysokiego poziomu stworzonym przez holenderskiego programistę Guido van Rossuma w~1990 roku.
# - Język został tak nazwany w ślad za programem telewizyjnym BBC "Latający cyrk Monty Pythona".
# - Obecnie Python rozwijany jest jako projekt Open Source, zarządzany przez Python Software Foundation, będącą organizacją non-profit.
# - Najnowszą stabilną wersją języka Python jest wersja 3.10.7, która została wydana 6 września 2022 roku.
# - W Pythonie to wartości, a nie zmienne, posiadają typ - tak więc Python jest językiem z typami dynamicznymi.
# - Python posiada wbudowane abstrakcyjne typy danych takie jak np. listy, krotki, zbiory i słowniki.
# - W Pythonie możliwe jest programowanie obiektowe, programowanie strukturalne i programowanie funkcyjne.
# - Do zarządzania pamięcią stosuje się **zbieranie nieużytków** (ang. garbage collection), tak więc Python nie wymaga od programisty ręcznego zarządzania pamięcią.
# - Cechą wyróżniającą Pythona spośród innych języków jest stosowanie wcięć do wydzielania bloków kodu.
# - Program napisany w języku Python najpierw kompilowany jest do postaci pośredniej, która następnie wykonywana jest przez Wirtualną Maszynę Pythona (PVM).
#
#
# ## Instalacja interpretera języka Python
# ### W systemie Linux
# - W Ubuntu Python 3 jest domyślnie zainstalowany
#
#
# ### W systemie Windows
# - Interpreter Pythona 3 można bezpłatnie pobrać ze strony [Pythona]
# - Pobieramy odpowiedni plik poprzez odpowiedni link
# - Instalujemy Pythona klikając na pobrany plik.
#
# ## Instalacja interpretera języka Python
# - Uruchomić stronę: https://www.python.org/downloads/
# - Kliknąć w przycisk "Pobierz Python [wersja]"

# %% [markdown]
# ![Screenshot-python-download.png](data:image/png;base64,...)

# %% [markdown]
# - Po zakończonym pobieraniu uruchomić instalator
#
# ![instalator.png](data:image/png;base64,...)

# %% [markdown]
# - Zaznaczyć checkboxy, jak na poniższym screenie. Kliknąć Install Now.
#
# ![checbox.png](data:image/png;base64,...)

# %% [markdown]
# - Kliknąć Close
#
# ![close.png](data:image/png;base64,...)

# %% [markdown]
# ## Instalacja środowiska programistycznego Pycharm
#
# - Uruchomić stronę: https://www.jetbrains.com/pycharm/download/#section=windows
# - Kliknąć przycisk Download (Community)
#
# ![pycharmdownload.png](data:image/png;base64,...)

# %% [markdown]
# - Po zakończonym pobieraniu uruchomić instalator
#
# ![instalatorpycharm.png](data:image/png;base64,...)

# %% [markdown]
# - Kliknąć Next
#
# ![next.png](data:image/png;base64,...)

# %% [markdown]
# - Za pomocą przycisku Browse można zmienić docelowy filder instalacji. Zalecane jest pozostawienie domyślnej lokalizacji instalacji, aby przejść dalej kliknąc przycisk  Next.
#
# ![next1.png](data:image/png;base64,...)

# %% [markdown]
# - Zaznaczyć checbox Add launchers dir to the PATH
# - Warto zaznaczyć checbox w sekcji Create Desktop Shortcut (zodny z wesrją systemu operacyjnego), aby na pulpicie pojawił się skrót do Pycharma
# - Warto również zaznaczyć checbox .py w sekcji Create Associations
# - Po zaznaczeniu checboxów kliknąć Next
#
# ![boxy.png](data:image/png;base64,...)

# %% [markdown]
# - Kliknąć Install
#
# ![instal.png](data:image/png;base64,...)

# %% [markdown]
# - Należy czekać, aż pasek postępu instalcji osiągnie 100%
#
# ![pstep.png](data:image/png;base64,...)

# %% [markdown]
# - Kliknąc Finish
# - Zakończenie procesu inatlacji może wymagać ponownego uruchomienia komputera
#
# ![finish.png](data:image/png;base64,...)

# %% [markdown]
# ## Uruchomienie środowiska Pycharm oraz utworzenie nowego projektu
#
# -  Kliknąć dwukrotnie w ikonę Pycharma na pulpicie, jeśli została dodana.
# W przeciwnym wypadku wyszukać Pycharma w Menu Start.
#
# ![klik.png](data:image/png;base64,...)

# %% [markdown]
# - Zaznaczyć checbox, jak na screenie.
# - Kliknąć Continue.
#
# ![continue..png](data:image/png;base64,...)

# %% [markdown]
# - W przyadku wyrażenia chęci dzieleniem się statystykami użycia należy zaznaczyć przycisk: Send Anonymous Statistics, w przeciwnym wypadku należy zaznaczyć przycisk: Don't Send.
#
# ![send.png](data:image/png;base64,...)

# %% [markdown]
# - W celu stworzenia nowego projektu kliknąć: New Project.
#
# ![newproject.png](data:image/png;base64,...)

# %% [markdown]
#  - Warto zostawić domyślną lokalizację. Zaleca się zmianę nazyw folderu, która jest jednocześnie nazwą projektu.
#  - Odnzaczyć checbox: Create a main.py welcome script.
#  - Kliknąc w przycisk: Create.
#
#  ![11111.png](data:image/png;base64,...)

# %% [markdown]
# - Jeżeli pojawi się okno ze wskazówkami przygotowanymi przez twóorców Pycharma warto się z nimi zapoznać.
#
# ![tip.png](data:image/png;base64,...)

# %% [markdown]
# - Pycharm został poprawnie skonfigutowany wraz z nowym projektem.
#
# ![projektnowy.png](data:image/png;base64,...)

# %% [markdown]
# - Kliknąć w strzałkę symbolizującą rozwijanie zawartości folderu. Znajduje się tam folder venv, który jest wirtualnym środowiskiem.
#
# ![strzalka.png](data:image/png;base64,...)

# %% [markdown]
# ## Hello World
#
# - Kliknąć prawym przyciskiem myszy na folder projektu. Kolejny wybrać New -> Python File.
#
# ![file.png](data:image/png;base64,...)

# %% [markdown]
# - Wprowadzić nazwę pliku(używać małych liter) oraz wybrać Python file.
#
# ![HW.png](data:image/png;base64,...)

# %% [markdown]
# - Prosty skrypt wyświetlający napis. W tym celu należy wpisać poniższy kod źródłowy w nowootwartej karcie edycji pliku źródłowego.

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ![Hello1.png](data:image/png;base64,...)

# %% [markdown]
# - W celu uruchomienia skryptu kliknąc prawym przyciskiem myszy w miejscu edycji kodu źródłowego i wybrać Run.
#
# ![Hello2.png](data:image/png;base64,...)

# %% [markdown]
# - Po uruchomieniu będzie widoczny następujący efekt.
#
# ![HelloTerminal.png](data:image/png;base64,...)

# %% [markdown]
# ## Środowisko wirtualne
#
# Środowisko wirtualne(venv - vurtualenv) zapewnia działanie skryptu napisanego w języku Python niezależnie od maszyny, na której jest uruchamiany, a także sposobem na uruchomienie innych programów na komputerze, tak aby instalowane z nią biblioteki nie zakłócały pracy innych skryptów. W praktyce wirtualne środowisko jest folderem o często używanej nazwie venv, który zawiera kopię pliku wykonywanego interpretera języka Python oraz pliki bibliotek używanych w projekcie. Dobrą praktyką jest wykorzystywanie oddzielnych środowisk wirtualnych dla każdego projektu. Środowisko wirtualne wymaga aktywacji, która zapewni wykonywanie skryptów za pomocą interpretera znajdującego się w tym środowisku (zamiast globalnego interpretera oraz globalnej bazy bibliotek - dostępnych dla całego systemu operacyjnego).

# %% [markdown]
# ### Środowisko wirtualne w Pycharm
#
# Środowisko wirtualne może zostać stworzone oraz aktywowane automatycznie podczas tworzenia nowego projektu, w tym celu należy zaznaczyć opcję w sekcji New environment using: Virtualenv. Dobra praktyką jest umieszczanie folderu środowiska wirtualnego w folderze projektu. W sekcji Base interpreter należy wskazać interpreter języka Python, który zostanie wykorzystany w środowisku wirtualnym.
#
# ![22222.png](data:image/png;base64,...)

# %% [markdown]
# ### Manualne tworzenie środowiska wirtualnego
#
# W tym celu należy uruchomić w wierszu poleceń następujące polecenie:
#
# c:\sciezka_do_inretpretera_python\python.exe -m venv c:\sciezka_projektu\venv

# %% [markdown]
# Takie środowisko należy również aktywować za pomocą następująego polecenia:
#
# sciezka_do_venv\Scripts\activate.bat

# %% [markdown]
# Po wykonaniu aktywacji w konsoli można zauważyć poniższy efekt:
#
# ![rurznie.png](data:image/png;base64,...)

# %% [markdown]
# ## Instalacja bibliotek
#
# Biblioteki instalujemy za pomocą narzędzia pip, które jest managerem bibliotek dla języka Python, domyślnie instalowanym wraz z interpreterem.
# Pod adresem: https://pypi.org/ można znaleźć obszerne repozytorium bibliotek języka Python.
#
# Biblioteki można zainstalować za pomocą nastepującego polecenia uruchamianego w wierszu poleceń:

# %%
pip install nazwa_pakietu
# Out:
# ERROR: Could not find a version that satisfies the requirement nazwa_pakietu (from versions: none)
# ERROR: No matching distribution found for nazwa_pakietu
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Należy mieć na uwadze, że biblioteki zostaną zainstalowane globalnie jeżeli środowisko wirtualne nie zostanie aktywowane. Biblioteki zainstalowane globalnie nie są dostępne w środowiskach wirtualnych.

# %% [markdown]
# ### Biblioteka phonenumbers
#
# Biblioteka phonenumbers służy do analizowania, przechowywania, formatowania, a także sprawdzania poprawności międzynarodowych numerów telefonów.
#
# W celu zainstalowania biblioteki phonenumbers należywpisać w terminalu pip install phonenumbers. Używając środowiska Pycharm można ułatwić proces z uwagi na automatycznie aktywowane środowisko wirtualne, co można zauważyć na poniższm screenie:
#
# ![phonenr.png](data:image/png;base64,...)

# %% [markdown]
# Po zakończonym procesie instalacji można zauważyć następujący komunikat:
#
# ![pndone.png](data:image/png;base64,...)

# %% [markdown]
# #### Przykład
# Wyświetlenie informacji o numerze telefonu +9606681400.
#
# W pierwszej kolejności należy dokonać importu pakietu, czego można dokonać za pomocą polecenia:

# %%
import nazwa_pakietu
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import nazwa_pakietu
#
# ModuleNotFoundError: No module named 'nazwa_pakietu'

# %% [markdown]
# Poniżej znajduje się przykład wykorzystania biblioteki phonenumbers w celu wyświetlenia informacji o numerze telefonu.

# %%
# !pip install phonenumbers

# %%
import phonenumbers

# %%
print(phonenumbers.parse('+48123456789', None))

# %% [markdown]
# ## Komentarze
#
# ### Komentarze jednoliniowe
#
# Komentarz w Pythonie rozpoczyna się od znaku # oraz ciągnie się do końca wiersza. Interpreter ignoruje tekst występujący po znaku #. Komentarze stosuje się do robienia notatek (np. "pozostało do zrobienia" przy pisaniu długiego kodu), wyjaśniania częsci kodu (np. dla osób, które będą później pracować z napisanym przez nas kodem).

# %%
a = 10
# To jest komentarz jednoliniowy
b = 'To nie jest # komentarz'
print(a)
print(b)

# %% [markdown]
# ### Komentarze wieloliniowe
#
# Komentarze wieloliniowe zapisujemy pomiędzy potrójnymi znakami ".

# %%
c = 2
"""
To jest
komentarz
wieloliniowy
"""
d = 'To nie jest komentarz'

# %% [markdown]
# ### Komentowanie kodu skrótem w środowisku Pycharm
#
# Pycharm posiada liczne skróty klawiszowe, wśród nich znajuje się skrót: "ctrl" oraz "?", co umożliwia automatyczne komentowanie pojedynczej linii, w której znajduje się kursor bądź zaznaczonych linii kodu.

# %% [markdown]
# ## Zasady organizacji kodu źródłowego z wykorzystaniem reguł PEP8
#
# Dokument PEP8 jest jedą z propozycji oganizacji kodu języka Python. Dokumnet znajduje się pod adresem: https://www.python.org/dev/peps/pep-0008/
#
#  - Zmienne nie mogą być liczbami

# %%
0 = 1

# %% [markdown]
# - Pliki, zmienne, metody i funkcje powinny być zapisywane małymi literami, a każde słowo łączymy znakiem _ (np variable_first) tzw. snake case

# %%
var_1 = 3
var_2 = 8

# %% [markdown]
# - Stałe zapisujemy wielkimi literami - również snake case

# %%
CONST_1 = 'WMP-UKSW'

# %% [markdown]
# - W Pythonie nie używa się znaków specjalnych do separacji bloków kodu, do tego celu wykorzystywane są odpowiednio ustawione wcięcia, które można umieścić korzystając z klaiwsza Tab. Istotną kwestią jest głębokość wcięć - musi być ujednolicona w obszarze całego kodu, przykładowo: 2 spacje, 4 spacje, itd.

# %%
if True:
    pass

# %% [markdown]
# - Klasy nazywa się wg konwencji Camel Case (np. MyClass). Wyrazy łączymy bez wykorzystania żandych dodatkowych znaków.

# %%
class MyClass:
    pass

# %% [markdown]
# - Pomiędzy funkcjami i klasami stosuje się 2 puste wiersze odstępu.

# %%
class MyClass1:
    pass


class MyClass2:
    pass


def foo1():
  pass


def foo2():
  pass

# %% [markdown]
# - Pomiędzy metodami w klasie stosuje się jeden pusty wiersz odstępu.

# %%
class MyClass:
  def meth1(self):
    pass

  def meth2(self):
    pass

# %% [markdown]
# - Na końcu każdego pliku musi znajdować się jeden pusty wiersz.

# %% [markdown]
# ## Zadania
#
# 1. Przygotować projekt pod nazwą lab1 z nowym aktywowanym środowiskiem wirtualnym
#
# 2. Przy użyciu zaimportowanego pakietu os (https://docs.python.org/3/library/os.html):
#   - wyświetlić bieżący katalog roboczy (funkcja getcwd)
#   - wyswietlić identyfikator bieżącego procesu (funkcja getpid)
#   - za pomocą funkcji mkdir utworzyć katalog test
#   - za pomocą funkcji rmdir usunąć katalog test
#
# 3. Zainstalować bibliotekę Faker (https://pypi.org/project/Faker/), a następnie:
#   - wyświetlić losowe imię i nazwisko
#   - wyświetlić losowy adres
#   - wyświetlić losowy tekst
#   - dodać komentarze jednoliniowe przy każdej wykorzystywanej funkcji
#   - sprawdzić czy wyświetlenie kilku losowych adresów/imion i nazwisk/tekstów wygeneruje różne wyniki
#
# 4. Wyświetlić listę wszystkich zainstalowanych bibliotek w środowisku wirtualnym za pomocą polecenia pip freeze uruchomionego w wierszu poleceń, a następnie zapisać wyjście w pliku requirements.txt, w głównym katalogu projektu
#
# 5. Utworzyć projekt lab1_2 z nowym aktywowanym środowiskiem wirtualnym (przy użyciu wiersza poleceń) i zainstalować wszystkie biblioteki używane w projekcie lab1. W tym celu należy skopiować plik requirements.txt (znajdujący się w projekcie lab1) do projektu lab1_2 i wpisać w terminalu polecenie: pip install -r requirements.txt
#
# 6. Zainstalować bibliotekę wikipedia (https://pypi.org/project/wikipedia/), a następnie:
#   - ustawić język polski dla przyszłych haseł
#   - wyświetlić podsumowanie artykułu znajdującego się pod hasłem "Python"
#   - wyświetlić adres URL artykułu znajdującego się pod hasłem "Mauritius"
#   - wyświetlić treść artykułu znajdującego się pod hasłem "Galapagos"

# %% [markdown]
# # Podstawy języka Python: zmienne i operacje na nich
#
# ## Metody wyświetlania danych (instrukcje wejścia)
#
# Instrukcje wyjścia służą do interakcji z użytkownikiem poprzez wyświetlanie danych. Podstawową instrukcją wyjścia w języku Python jest funkcja print().
#
#
#
#
# ### Wyświetlanie tekstu stałego
#
# W celu wyświetlenia tekstu należy użyć funkcji print(), tekst, który ma zostać wyświetlony należy umieścić w '  ' lub w "  ".

# %%
print('hello world')
print("hello world")

# %% [markdown]
# ### Wyświetlanie tekstu ze zmiennej
#
# W celu wyświetlenia tekstu ze zmiennej należy utworzyć zmienną i po znaku = przypisać jej tekst, który ma zostać wyświetlony. Następnie przy użyciu funkcji print() wyświetlić wartość zmiennej.

# %%
var = 'Hello world'

print(var)

# %% [markdown]
# ## Wartości liczbowe
#
# ### statyczna wartośc liczbowa
#
# W celu wyświetlenia statycznej wartość liczbowej należy przekazać tą wartość.

# %%
print(10)

# %% [markdown]
# ### Wartość liczbowa ze zmiennej
#
# W celu wyświetlenia wartości liczbowej ze zmiennej należy utworzyć zmienną i po znaku = przypisać jej wartość, która ma zostać wyświetlona. Następnie przy użyciu funkcji print() wyświetlić wartość zmiennej.

# %%
var = 10

print(var)

# %% [markdown]
# ### Wyświetlanie wartości wyrażenia
#
# Do funkcji print należy przekazac proste wyrażenie arytymetyczne. W wyniku tego wyświetli się wartość wyrażenia.

# %%
print(2 + 2)

# %% [markdown]
# ## Typy liczbowe
# - W języku Python dostępne są następujące rodzaje liczb:
#     - całkowite (0, 1, 2 itd.) - typ int
#     - boolowskie (tylko wartości False oraz True) - typ bool
#     - zmiennoprzecinkowe (3.14, 2.718, itd.) - typ float
#     - zespolone (2+3j, 1j, 1+0j) - typ complex
# - Operatory arytmetyczne:
#     - dodawanie + oraz odejmowanie -
#     - mnożenie *, dzielenie /, dzielenie całkowite //
#     - reszta z dzielenia całkowitego %
#     - potęgowanie **
# - Operatory z operandami typów mieszanych przekształcają
#     - operandy boolowskie w całkowite, zmiennoprzecinkowe lub zespolone
#     - operandy całkowite w zmiennoprzecinkowe lub zespolone
#     - operandy zmiennoprzecinkowe w zespolone.
#
# ## Obiekty, wartości i typy
#  - Obiekty są w Pythonie abstrakcją danych.
#  - Każda dana jest reprezentowana przez obiekt lub przez relację pomiędzy obiektami.
#  - Zgodnie z modelem "komputera z programem w pamięci" von Neumanna kod również reprezentowany jest przez obiekty.
#  - Każdy obiekt ma tożsamość, typ i wartość.
#  - Od chwili utworzenia obiektu jego tożsamość nigdy się nie zmienia.
#  - O tożsamości obiektu można myśleć jak o adresie obiektu w pamięci.
#  - Do porównania tożsamości dwóch obiektów służy operator is.
#  - Wbudowana funkcja id zwraca wartość całkowitą, reprezentującą tożsamość obiektu.
#  - W standardowej implementacji funkcja ta zwraca adres obiektu, przekształcony do postaci liczbowej.
#  - Typ określa zbiór atrybutów i operacji, które można wykonać na obiekcie oraz definiuje zbiór dopuszczalnych wartości obiektu.
#  - Typ obiektu, podobnie jak jego tożsamość, również nie może ulec zmianie.
#  - Typ obiektu (który również jest obiektem) można pobrać za pomocą wbudowanej funkcji type.
#
# ## Zmienne i metody ich inicjalizacji
# - Zmienna w Pythonie jest nazwą, która jest odniesieniem do obiektu.
# - Aby utworzyć zmienną oraz nadać jej wartość należy użyć instrukcji przypisania czyli inicjalizujemy podstwiając do nich wartości po  znaku =.

# %%
zmienna = "Ala ma kota"

# %% [markdown]
# - Powyższa instukcja przypisuje do zmiennej zmienna odniesienie do obiektu utworzonego w wyniku obliczenia wartości wyrażenia
# - Wartość może być przypisana jednocześnie wielu zmiennym, np.

# %%
a, b, c = 3, 4, 5
a, b = b, a

# %% [markdown]
# ### Zmienna tekstowa
#
# Do zmiennej należy podtswić tekst zapisany w ' '  lub " ".

# %%
var_str = 'to jest tekst'

print(var_str)

# %%
var_str = 'to jest \'kolejny\' tekst'

print(var_str)

# %% [markdown]
# Zmienna całkowitoliczbowa
#
# Do zmiennej po znaku = należy podstawić liczbę całkowitą.

# %%
var_int = 2611

print(var_int)

# %% [markdown]
# Zmienna rzeczywista
#
# Do zmiennej po znaku = należy podstawić liczbę rzeczywistą.
# Alternatywnie można wpisać wartość zakończoną separatorem miejsc dziesiętnych, wówczas 0 zostanie automatycznie dodane przez interpreter. Można również użyć funkjci float(), do której zostanie przekazana wartość całkowita.

# %%
var_float_0 = 10.0
var_int = 10

print(type(var_float_0))
print(type(var_int))

var_float_1 = 10.
var_float_2 = float(10)

print(var_float_0)
print(var_float_1)
print(var_float_2)

# %% [markdown]
# Zmienna logiczna
#
# Do zmiennej podstawiamy wartość logiczną True(Prawda) lub False(Fałsz).

# %%
var_bool_0 = False
var_bool_1 = True

print(var_bool_0)
print(var_bool_1)
print(var_bool_0 == var_bool_1)

# %% [markdown]
# ## Rzutowanie typów danych (konwersja)
#
# Zdarza się, że potrzebny jest inny typ danych niż jest dostępny. Pyhton uodstępnia możliwość przekonwertowania typu wartości znajdującego się w zmiennej na iny typ.
#
# ### Pobieranie typów zmiennych
#
# Przed dokonaniem rzutowania istotnym korkiem jest sprawdzenie, jakiego typu wartość znajduje się w zmiennej.
# Można tego dokonać używając funkcji type().

# %%
a = 20
b = 80.1
c = 'tekst'

type_of_a = type(a)
type_of_b = type(b)
type_of_c = type(c)

print(type_of_a)
print(type_of_b)
print(type_of_c)

print(type(type_of_a))

# %%
type(16)

# %%
type("Hello")

# %%
type("16")

# %%
type(3.14)

# %%
type(2**100000000)

# %%
type(1 > 0)

# %%
type(False)

# %%
type(True)

# %%
type(None)

# %%
type(1 + 2j)

# %% [markdown]
# ### Priorytety operatorów
# - Nawiasy mają najwyższy priorytet. Są używane do wymuszenia obliczania wartości wyrażenia w żądanej kolejności,
#  - Potęgowanie ma kolejny najwyższy priorytet.
#  - Mnożenie, dzielenie, dzielenie całkowite i reszta z dzielenia mają ten sam priorytet, który jest wyższy niż dodawanie i odejmowanie, które również mają ten sam priorytet.
#  - Operatory o tym samym priorytecie są obliczane od lewej do prawej. W algebrze mówimy, że są lewostronnie łączne.
#  - Wyjątkiem (z powodów historycznych) jest operator potęgowania, który jest prawostronnie łączny.
#
#
# ### Operatory porównania
#  - Python oferuje standardowy zestaw binarnych operatorów porównania charakteryzujących się oczekiwaną semantyką:
#  - < (mniejszy niż),
#  - \> (większy niż),
#  - == (równy),
#  - != (różny
#  - \<= (mniejszy lub równy),
#  - \>= (większy lub równy),
#  - Wymienione operatory porównują wartości obiektów, do których odniesienia zostały wskazane w operatorze.
#  - Wynikiem porównania jest wartość typu bool: False albo True.
#  - Porównania, które nie mają sensu, będą powodowały zgłoszenie wyjątku.
#
# ### Sprawdzanie typów zmiennych
#
# Alternatywną metodą jest sprawdzenie, czy wartość znajdująca się w zmiennej jest tego typu, którego oczekujemy.
# Służy do tego funkcja isinstance().

# %%
print(isinstance(a, int))
print(isinstance(c, float))
c

# %% [markdown]
# ### Konwersja typów zmiennych

# %%
var_float = 10.2
var_int = 20
var_int_bool = 0
var_str = '90'
var_bool = True

# %% [markdown]
# Konwersja z typu zmiennoprzecinkowego (float) na typ całkowitoliczbowy (int).

# %%
float_to_int = int(var_float)

print(type(float_to_int))
print(type(var_float))

print('-------------------')

print(float_to_int)
print(var_float)

# %% [markdown]
# Konwersja z typu całkowitoliczbowego (int) na typ zmiennoprzecinkowy (float).

# %%
int_to_float = float(var_int)

print(type(var_int))
print(type(int_to_float))

print('-------------------')

print(var_int)
print(int_to_float)

# %% [markdown]
# Konwersja z typu tekstowego(str) na typ calkowitoliczboy (int).
#
# W  tym przypadku należy uważać ponieważ tekst przy takiej konwersji powinien zawierać jedynie cyfry.

# %%
str_to_int = int(var_str)

print(type(var_str))
print(type(str_to_int))

print('-------------------')

print(var_str)
print(str_to_int)

int('to jest 2 mieszany tekst 1')

# %% [markdown]
# Konwersja z typu tekstowego (str) na typ zmiennoprzecinkowy (float).

# %%
str_to_float = float(var_str)

print(type(var_str))
print(type(str_to_float))

print('-------------------')

print(var_str)
print(str_to_float)

# %% [markdown]
# Konwersja z typu całkowitoliczbowego (int) na typ logiczny (bool).

# %%
int_to_bool = bool(var_int_bool)

print(type(var_int_bool))
print(type(int_to_bool))

print('-------------------')

print(var_int_bool)
print(int_to_bool)

# %% [markdown]
# Konwersja z typu logicznego (bool) na typ tekstowy (str).

# %%
bool_to_str = str(var_bool)

print(type(var_bool))
print(type(bool_to_str))

print('-------------------')

print(var_bool)
print(bool_to_str)

# %% [markdown]
# ## Wczytywanie danych od użytkownika (instrukcje wejścia)
#
# Jedną z najbardziej podstawowych instrukcji wejścia jest funkcja input, służy ona do wczytywania wartości wpisanych przez uzytkownika za pomocą klawiatury. Domyślnie wartości wpisane z kalwiatury są typu tesktowego (str).
#
# ### Wczytywanie wartości tekstowych
#
# W celu wczytania wartości tekstowej wprowadzonej przez uzytkownika należy użyć funkcji input z przekazaną instrukcją dla użytkownika, wynik funckji powinien być podstawiony do zmiennej.

# %%
input_value = input('Wprowadz tekst: ')

print(input_value)

# %% [markdown]
# ### Wczytywanie wartości całkowitoliczbowych
#
# W celu wczytania wartości wprowadzonej przez uzytkownika należy użyć funkcji input z przekazaną instrukcją dla użytkownika, wynik funckji powinien być podstawiony do zmiennej. Należy pamiętać, że każda wartośc wpisna z klawiatury jest typu tekstowego (str) zatem należy dokonać konwersji na typ całkowitoliczbowy (int). Muszą być wprowadzone same cyfry!

# %%
input_int_value = int(input('Wprowadz liczbe calkowita: '))

print(input_int_value)
print(type(input_int_value))

# %% [markdown]
# ### Wczytywanie wartości rzeczywistych
#
# W celu wczytania wartości wprowadzonej przez uzytkownika należy użyć funkcji input z przekazaną instrukcją dla użytkownika, wynik funckji powinien być podstawiony do zmiennej. Należy pamiętać, że każda wartośc wpisna z klawiatury jest typu tekstowego (str) zatem należy dokonać konwersji na typ rzeczywisty (float). Muszą być wprowadzone same cyfry i separator, jako .!

# %%
input_float_value = float(input('Wprowadz liczbe: '))

print(input_float_value)
print(type(input_float_value))

# %% [markdown]
# ## Działania arytmetyczne
#
# W Pythonie istnieje możlwiość wykonywania działań arytymetycznych za pomocą operatorów. Wyrażenie arytymetyczne może skadać się z wielu operatorów.
#
# ### Podstawowe operatory arytmetyczne
#
# - operator dodawania: +
# - operator odejmowania: -
# - operator mnożenia: *
# - operator dzielenia całowitego: //
# - operator modulo, reszta z dzielenia: %
# - operator potęgowania: **

# %%
a = 10
b = 20

addition = a + b
substraction = a - b
multiplication = a * b
division = a / b

print(addition)
print(substraction)
print(multiplication)
print(division)

# %% [markdown]
# Należy pamiętać, że nie dzielimy przez 0.

# %%
print(10 / 0)

# %% [markdown]
# ### Dzielenie całkowite

# %%
print(10 // 3)

# %% [markdown]
# ### Reszta z dzielenia

# %%
print(11 % 4)

# %% [markdown]
# ### Potęgowanie
#
# $$2^{10}$$

# %%
print(2 ** 10)

# %% [markdown]
# ### Pierwiastkowanie
#
# W celu wykonania operacji pierwiastkowania należy uzyć modułu math (moduł należy zaimportować).
#
# $$\sqrt{10}$$

# %%
import math

print(math.sqrt(10))

# %% [markdown]
# ### Logarytmy
#
# Do wykonywania działań na logarytmach również niezbędny jest moduł math.
#
# $$log_{2}(5)$$

# %%
import math

print(math.log(5, 2))

# %% [markdown]
# ### Liczba e
#
# Wartośc liczby e jest dostępna w module math.

# %%
print(math.e)

# %% [markdown]
# ### Liczba pi
#
# Wartośc liczby pi jest również dostępna w  module math.

# %%
print(math.pi)

# %% [markdown]
# ### Trygonometria
#
# Wartości funkcji trygonometrycznych są dostępne w module math.
#
# sinus

# %%
print(math.sin(20))

# %% [markdown]
# cosinus

# %%
print(math.cos(30))

# %% [markdown]
# tangens

# %%
print(math.tan(60))

# %% [markdown]
# ### Liczby zespolone
#
# Python umożliwia wynonywanie działań na liczbach zespolonych bez dodatkowych bibliotek.

# %%
z = 3 + 4j

print(z)

# %% [markdown]
# Wartość rzeczywista i urojona
#
# W łatwy sposób można wyodrębnić zarówno część rzeczywistą, jak i częśc urojoną liczby zespolonej.

# %%
print(z.real)  # wartosc rzeczywista
print(z.imag)  # wartosc urojona

# %% [markdown]
# Działania na liczbach zespolonych
#
# Na ciele liczb zespolonych można dokonywać działań.

# %%
z0 = 5 + 2j
z1 = 9 + 6j

print(z0 + z1)
print(z0 / z1)
print(z0 ** z1)

# %% [markdown]
# ## Typy zmiennych
#
# W języku Python od wersji 3.5 można nadawać typy zmiennym
#
# - int - liczba całkowita
# - float - liczba rzeczywista
# - str - wartość tekstowa
# - bool - wartość logiczna.
#
# Typ może zostać nadany w momencie inicjalizacji  zmiennej.

# %%
var_0: int = 10
var_1: float = 20.0
var_2: str = 'lorem ipsum'
var_3: bool = False

print(var_0)
print(type(var_0))
print(var_2)
print(var_3)

# %% [markdown]
# Należy mieć na uwadze, że zadeklarowane typy zmiennych nie mają wpływu na ich faktyczną wartość.

# %%
var_any: str = 20

print(var_any)
print(type(var_any))
print(isinstance(var_any, str))

# %% [markdown]
# ## Operatory przyrostkowe
#
#
#
# Zamiast:

# %%
a = 10

a = a + 9

# %% [markdown]
# piszemy:

# %%
a += 9

a *= 3

a -= 10

a /= 3

# %% [markdown]
# ## Ciągi znaków i operacje na nich

# %%
var_str = 'to jest tekst!'

# %% [markdown]
# ### Długość tekstu
#
# W celu sprawdzenia dlugości tekstu należy użyć funkcji len().

# %%
var_str_len = len(var_str)

print(var_str_len)

# %% [markdown]
# ### Odwoływanie się do znaków na konkretnych pozycjach
#
# Do celów odwołania się do konkretnej pozycji nalezy uzyć [].
# Należy pamiętać, że pierwszy znak jest na pozycji 0.
#
# Pierwszy znak:

# %%
print(var_str[0])

# %% [markdown]
# Ostatni znak:

# %%
print(var_str[-1])

# %% [markdown]
# Przedostatni znak:

# %%
print(var_str[-2])

# %% [markdown]
# Można również wyświetlić fragment tekstu.
#
# Fragment tekstu na pozycjach od 3 do 6.

# %%
print(var_str[3:7])

# %% [markdown]
# ### Zmiana wielkości znaków
#
# Python umożliwia zmianę małych liter na wielkie, w tym celu nalezy użyć metody upper().

# %%
var_str_low: str = 'to sa male litery'

print(var_str_low)
print(var_str_low.upper())

# %% [markdown]
# Istnieje również możliwośc zmiany wielkich liter na małe, w tym celu nalezy użyć metody lower().

# %%
var_str_up: str = 'TO SA WIELKIE LITERY'

print(var_str_up)
print(var_str_up.lower())

# %% [markdown]
# Można rówież zmienić wielkości pierwszych liter każdego słowa na wielką literę - metoda title().

# %%
var_str: str = 'to jest prosty tekst'

print(var_str)
print(var_str.title())

# %% [markdown]
# ### Interpolacja tekstów (f-string)
#
# Dzięki interpolacji tektów można w łatwy sposób umieszczać różne wartości w tekscie.

# %%
lines_count: int = 3200
space_avg: float = 3.5

summary: str = f'Objetosc kodu wynosi {lines_count} linii, gdzie na kazda linie przypada srednio {space_avg} spacji'
print(summary)

summary_1: str = "Objetosc kodu wynosi " + str(lines_count) + " linii, gdzie na kazda linie przypada srednio " + str(space_avg) + " spacji"
print(summary_1)

# %% [markdown]
# ## Słowa kluczowe
# - Nazwy zmiennych, funkcji i klas sa˛ identyfikatorami.
# - Identyfikator to dowolny ciąg składający się z liter, cyfr oraz znaków podkreślenia zaczynajacy się litery lub znaku odkreślenia.
# - Spośród wszystkich możliwych nazw zmiennych 33 są zarezerwowane. Są to słowa kluczowe jezyka Python.

# %% [markdown]
# ![klczowe.png](data:image/png;base64,...)

# %% [markdown]
# ## Zadania - Sekwencyjne programy w Pythonie wykorzystujące funkcję print
#
# 1. Napisz program, który wypisuje sumę dni pierwszych trzech miesięcy dowolnego roku przestępnego.
#
# 2. Napisz program, który wypisuje sumę pierwszych dziesięciu liczb całkowitych dodatnich, 1 + 2 + ... + 10
#
# 3. Napisz program, który drukuje iloczyn pierwszych dziesięciu liczb całkowitych dodatnich, 1 * 2 * ... * 10.
#
# 4. Załóżmy, że żyjemy i zarabiamy 20 lat temu... Napisz program, który drukuje saldo konta po pierwszym, drugim i trzecim roku. Na koncie jest początkowo 1000 zł a oprocentowanie wynosi 6 procent rocznie.
